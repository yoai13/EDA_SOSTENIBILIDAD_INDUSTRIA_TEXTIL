# %%
import pandas as pd

# %%
df = pd.read_csv("Plastic based Textiles in clothing industry updated.csv")
df
# Out:
#                Company     Product_Type Eco friendly     Country  \
# 0                 Zara        Polyester        Least   Indonesia
# 1                 Zara            Nylon        Least  Bangladesh
# 2                 Zara    Recycled_Poly     Moderate      France
# 3                 Zara           Cotton        Least       India
# 4                 Zara  Synthetic_Blend        Least       India
# ...                ...              ...          ...         ...
# 6951            Adidas           Tencel         Most     Denmark
# 6952  Urban Outfitters       Microfiber     Moderate       Spain
# 6953  Urban Outfitters   Organic_Cotton         Most      Norway
# 6954            Adidas       Microfiber     Moderate      Mexico
# 6955  Urban Outfitters            Nylon        Least       China
#
#       Production_Year  Greenhouse_Gas_Emissions  Pollutants_Emitted  \
# 0                2020                      4501                  20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6956 entries, 0 to 6955
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   6956 non-null   object
#  1   Product_Type              6956 non-null   object
#  2   Eco friendly              6956 non-null   object
#  3   Country                   6956 non-null   object
#  4   Production_Year           6956 non-null   int64
#  5   Greenhouse_Gas_Emissions  6956 non-null   int64
#  6   Pollutants_Emitted        6956 non-null   int64
#  7   Water_Consumption         6956 non-null   int64
#  8   Energy_Consumption        6956 non-null   int64
#  9   Waste_Generation          6956 non-null   int64
#  10  Sales_Revenue             6956 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 597.9+ KB
